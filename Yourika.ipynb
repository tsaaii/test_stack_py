# %%
import pandas as pd
import urllib
import re
import schedule
import time
from datetime import datetime
import json
from stackapi import StackAPI
from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)

# %%
def job():
    t= datetime.now()
    y=int(time.mktime(t.timetuple()))
    SITE = StackAPI('math.meta')
    questions = SITE.fetch('Answers',tag='linear-algebra',fromdate=1537462188, todate=y,sort='votes')
    for items in questions:
        x=questions['items']
        df=pd.DataFrame(x)
        p=df['owner']
        d=p.to_dict()
        dfd=pd.DataFrame(d)
        f1=dfd.T
        f2=f1[['display_name','link','user_id']]
        f2.to_sql('users', con=engine)
        print('updated at',t)
schedule.every(10).seconds.do(job)  
for i in range(0,1):
    schedule.run_pending()
    time.sleep(1)
    i=2
# Out:
#              display_name                                               link  \
# 0      Michael Greinecker  https://math.meta.stackexchange.com/users/2167...
# 1                rschwieb  https://math.meta.stackexchange.com/users/2933...
# 2                    John  https://math.meta.stackexchange.com/users/7163...
# 3                  Hurkyl  https://math.meta.stackexchange.com/users/1497...
# 4                  Hurkyl  https://math.meta.stackexchange.com/users/1497...
# 5          Aloizio Macedo  https://math.meta.stackexchange.com/users/5923...
# 6           Gerry Myerson  https://math.meta.stackexchange.com/users/8269...
# 7                   amWhy  https://math.meta.stackexchange.com/users/9003...
# 8                    quid  https://math.meta.stackexchange.com/users/8530...
# 9             Noah Snyder  https://math.meta.stackexchange.com/users/8/no...
# 10     Michael Greinecker  https://math.meta.stackexchange.com/users/2167...
# ...

# %%
engine.execute("SELECT * FROM users").fetchall()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#
# OperationalError: no such table: users
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-28-fe04181683e2> in <module>()
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-9b22214c9c99> in <module>()
# ----> 1 f2.to_sql('questions', con=engine)
#
# NameError: name 'f2' is not defined

# %%
for i in range(0,100):
    print('this is a test document to fool your system ok?')
    i=i+1
# Out:
# this is a test document to fool your system ok?
# this is a test document to fool your system ok?
# this is a test document to fool your system ok?
# this is a test document to fool your system ok?
# this is a test document to fool your system ok?
# this is a test document to fool your system ok?
# this is a test document to fool your system ok?
# this is a test document to fool your system ok?
# this is a test document to fool your system ok?
# this is a test document to fool your system ok?
# this is a test document to fool your system ok?
# this is a test document to fool your system ok?
# this is a test document to fool your system ok?
# this is a test document to fool your system ok?
# this is a test document to fool your system ok?
# this is a test document to fool your system ok?
# this is a test document to fool your system ok?
# this is a test document to fool your system ok?
# this is a test document to fool your system ok?
# this is a test document to fool your system ok?
# ...

# %%
# %tb
# Out:
# ---------------------------------------------------------------------------
# SystemExit                                Traceback (most recent call last)
# <ipython-input-1-c3aec4598bd2> in <module>()
#      32
#      33 if __name__ == "__main__":
# ---> 34     app.run(host='0.0.0.0', port=5001, debug=True)
#
# ~/anaconda3/lib/python3.6/site-packages/flask/app.py in run(self, host, port, debug, **options)
#     839         options.setdefault('use_debugger', self.debug)
#     840         try:
# --> 841             run_simple(host, port, self, **options)
#     842         finally:
#     843             # reset the first request information if the development server
#
# ~/anaconda3/lib/python3.6/site-packages/werkzeug/serving.py in run_simple(hostname, port, application, use_reloader, use_debugger, use_evalex, extra_files, reloader_interval, reloader_type, threaded, processes, request_handler, static_files, passthrough_errors, ssl_context)
# ...

# %%
import os
from flask import Flask, render_template, request

__author__ = 'ibininja'

app = Flask(__name__)

#APP_ROOT = os.path.dirname(os.path.abspath(__file__))

@app.route("/")
def index():
    return render_template("upload.html")

@app.route("/upload", methods=['POST'])
def upload():
    target = os.path.join(APP_ROOT, 'images/')
    print(target)

    if not os.path.isdir(target):
        os.mkdir(target)

    for file in request.files.getlist("file"):
        print(file)
        filename = file.filename
        destination = "/".join([target, filename])
        print(destination)
        file.save(destination)

    return render_template("complete.html")

if __name__ == "__main__":
    app.run(port=5000, debug=True)
# Out:
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /Users/sai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2918: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
exit

# %%
from flask import Flask, render_template, request
from werkzeug import secure_filename
app = Flask(__name__)

@app.route('/upload')
def upload_file():
   return render_template('upload.html')

@app.route('/uploader', methods = ['GET', 'POST'])
def uploading_file():
   if request.method == 'POST':
      f = request.files['file']
      f.save(secure_filename(f.filename))
      return 'file uploaded successfully'

if __name__ == '__main__':
   app.run(debug = True)
# Out:
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /Users/sai/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2918: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
exit

# %%
# importing required modules 
import PyPDF2

# %%
# creating a pdf file object 
pdfFileObj = open('1.pdf', 'rb')

# %%
# creating a pdf reader object 
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

# %%
  
# printing number of pages in pdf file 
print(pdfReader.getDocumentInfo())
# Out:
# {'/Author': 'Antonio Gulli', '/CreationDate': "D:20180821023455+00'00'", '/Creator': 'calibre 3.27.1 [https://calibre-ebook.com]', '/Producer': 'calibre 3.27.1 [https://calibre-ebook.com]', '/Title': 'A collection of Data Science Interview Questions Solved in Python and Spark: BigData and Machine Learning in Python and Spark (A Collection of Programming Interview Questions Book 6)'}

# %%
print(pdfReader.getFields())
# Out:
# None

# %%
pdfReader.getFormTextFields
# Out:
# <bound method PdfFileReader.getFormTextFields of <PyPDF2.pdf.PdfFileReader object at 0x10cbabba8>>

# %%
pdfReader.getOutlines()
# Out:
# [{'/Left': 72,
#   '/Page': {'/Annots': [IndirectObject(794, 0),
#     IndirectObject(795, 0),
#     IndirectObject(796, 0),
#     IndirectObject(797, 0),
#     IndirectObject(798, 0)],
#    '/Contents': {'/DL': 8895, '/Filter': ['/FlateDecode']},
#    '/Parent': {'/Count': 111,
#     '/Kids': [IndirectObject(6, 0),
#      IndirectObject(16, 0),
#      IndirectObject(18, 0),
#      IndirectObject(23, 0),
#      IndirectObject(25, 0),
#      IndirectObject(30, 0),
#      IndirectObject(32, 0),
#      IndirectObject(34, 0),
#      IndirectObject(37, 0),
#      IndirectObject(39, 0),
#      IndirectObject(41, 0),
#      IndirectObject(43, 0),
#      IndirectObject(51, 0),
#      IndirectObject(53, 0),
#      IndirectObject(62, 0),
#      IndirectObject(64, 0),
#      IndirectObject(66, 0),
#      IndirectObject(74, 0),
#      IndirectObject(79, 0),
#      IndirectObject(81, 0),
#      IndirectObject(84, 0),
#      IndirectObject(88, 0),
#      IndirectObject(90, 0),
# ...

# %%
type(pdfReader.getXmpMetadata())#See if you can print whats inside
# Out:
# PyPDF2.xmp.XmpInformation

# %%
# creating a page object 
pageObj = pdfReader.getPage(7)

# %%
# extracting text from page 
pageObj.extractText()
# Out:
# ''

# %%
  
# closing the pdf file object 
pdfFileObj.close()

# %%
()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-eaf6bfabde3c> in <module>()
# ----> 1 pdfFileObj.PageLayout()
#
# AttributeError: '_io.BufferedReader' object has no attribute 'PageLayout'

# %%
import xml.etree.ElementTree as ET

class LogParser:

    @staticmethod
    def ids_by_message(xml, message):
        xml = """<?xml version="1.0" encoding="UTF-8"?>
<log>
    <entry id="1">
        <message>Application started</message>
    </entry>
    <entry id="2">
        <message>Application ended</message>
    </entry>
</log>"""
        
        root= ET.fromstring(xml)
print(LogParser.ids_by_message(xml, 'Application ended'))
# Out:
# None

# %%
xml = """<?xml version="1.0" encoding="UTF-8"?>
<log>
    <entry id="1">
        <message>Application started</message>
    </entry>
    <entry id="2">
        <message>Application ended</message>
    </entry>
</log>"""

# %%
root= ET.fromstring(xml)

# %%
print(root.attrib)
# Out:
# {}

# %%
for child in root:
    for keys in child.attrib:
        x=(child.attrib[keys])
        print(x[0])
# Out:
# 1
# 2
